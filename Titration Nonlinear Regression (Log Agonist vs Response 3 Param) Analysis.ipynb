# %%
import pandas as pd, ipywidgets as widgets, numpy as np, matplotlib.pyplot as plt, io, seaborn as sns
from ipywidgets import interact, interactive, fixed, interact_manual
from scipy.optimize import curve_fit

raw_uploader = widgets.FileUpload(multiple = False)
display(raw_uploader)
# Out:
# FileUpload(value={}, description='Upload')

# %%
iquename = list(raw_uploader.value.keys())[0]
iquedata = pd.read_csv(io.BytesIO(raw_uploader.value[iquename]['content']))
iquedata.rename(columns = {'Plate' : 'iQue3 Plate','Well ID':'iQue3 384 Well ID'}, inplace = True)
iquedata
# Out:
#                                       Experiment    Analysis   iQue3 Plate  \
# 0     22_10_28 Xyphos A2a Titrations BPP618 P1-2  Analysis 1       Plate 1
# 1     22_10_28 Xyphos A2a Titrations BPP618 P1-2  Analysis 1       Plate 1
# 2     22_10_28 Xyphos A2a Titrations BPP618 P1-2  Analysis 1       Plate 1
# 3     22_10_28 Xyphos A2a Titrations BPP618 P1-2  Analysis 1       Plate 1
# 4     22_10_28 Xyphos A2a Titrations BPP618 P1-2  Analysis 1       Plate 1
# ...                                          ...         ...           ...
# 1019  22_10_28 Xyphos A2a Titrations BPP618 P1-2  Analysis 1  Plate 2 redo
# 1020  22_10_28 Xyphos A2a Titrations BPP618 P1-2  Analysis 1  Plate 2 redo
# 1021  22_10_28 Xyphos A2a Titrations BPP618 P1-2  Analysis 1  Plate 2 redo
# 1022  22_10_28 Xyphos A2a Titrations BPP618 P1-2  Analysis 1  Plate 2 redo
# 1023  22_10_28 Xyphos A2a Titrations BPP618 P1-2  Analysis 1  Plate 2 redo
#
# ...

# %%
pivot_data = iquedata[["iQue3 Plate", "Row", "Column", "Well Type", "Median RL1-H of singlets", "Count of singlets"]]
pivot_data["iQue3 Plate+Well"] = (pivot_data["iQue3 Plate"] + "-" + pivot_data["Column"].astype(str))
pivot_data = pivot_data[["Median RL1-H of singlets", "iQue3 Plate+Well"]]
pivot_data
n = pd.Series([1,2])
n
#pivot_data = pd.concat([pivot_data, n], axis = 1, ignore_index = True)
# Out:
# /var/folders/k8/mg372j_55z30k1z4y_8mb0w00000gn/T/ipykernel_7017/3115884842.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pivot_data["iQue3 Plate+Well"] = (pivot_data["iQue3 Plate"] + "-" + pivot_data["Column"].astype(str))
# 0    1
# 1    2
# dtype: int64

# %%
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# /var/folders/k8/mg372j_55z30k1z4y_8mb0w00000gn/T/ipykernel_7017/152755110.py in <module>
# ----> 1 pivot_data.fillna(n, axis=1, inplace = True)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in fillna(self, value, method, axis, inplace, limit, downcast)
#    5221         downcast=None,
#    5222     ) -> DataFrame | None:
# -> 5223         return super().fillna(
#    5224             value=value,
#    5225             method=method,
#
# ...
